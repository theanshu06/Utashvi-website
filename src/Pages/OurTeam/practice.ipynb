# %% [markdown]
# # Practice Notebook
#
# This is a rough practice notebook for testing and experimentation.

# %%
# Practice cell 1
print("Hello, World!")

# %%
# Practice cell 2
import numpy as np
import pandas as pd

# %%
# Add your practice code here
